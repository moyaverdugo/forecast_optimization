# %% [markdown]
# # Capstone: Portfolio Optimization

# %%
#Base
import numpy as np
import pandas as pd
from datetime import datetime

#Visualization
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objs as go

#Data Optimization
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import cross_val_score

#Analysis
import statsmodels.api as sm
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from scipy.optimize import minimize
import cvxpy as cp

# %% [markdown]
# # 1. Data Wrangling

# %% [markdown]
# ### 1.1 Upload the csv files

# %%
df=pd.read_csv('forecast2.csv')

# %% [markdown]
# ### 1.2 Data Exploration & Preparation

# %%
#We can see all the columns with the close suffix that is the closing price
#and volume that is the number of transactions.
df.head(1)
# Out:
#          date  AAL_close  AAPL_close   AAP_close  ABC_close  ABT_close  \
# 0  2020-02-07  28.379999     80.0075  132.929993  91.940002  87.870003
#
#     ACN_close  ADBE_close   ADI_close  ADM_close  ...  WU_close  WYNN_close  \
# 0  211.580002  366.089996  112.269997  45.709999  ...     27.65  126.910004
#
#    WY_close  XEL_close  XOM_close  XRAY_close  XRX_close   YUM_close  \
# 0     28.58  68.709999  61.470001   57.099998  37.169998  102.040001
#
#     ZBH_close  ZION_close
# 0  151.834946       46.23
#
# [1 rows x 397 columns]

# %%
df = df.iloc[:, 1:477].copy()
df
# Out:
#       AAL_close  AAPL_close   AAP_close   ABC_close   ABT_close   ACN_close  \
# 0     28.379999   80.007500  132.929993   91.940002   87.870003  211.580002
# 1     28.379999   80.007500  132.929993   91.940002   87.870003  211.580002
# 2     28.379999   80.007500  132.929993   91.940002   87.870003  211.580002
# 3     28.790001   80.387497  130.679993   93.599998   88.300003  212.550003
# 4     29.840000   79.902496  132.110001   94.570000   89.169998  212.139999
# ...         ...         ...         ...         ...         ...         ...
# 1092 -48.992513  184.641510  183.486600  124.690785  167.656430  405.435459
# 1093 -47.555013  183.117147  182.736600  124.490467  167.265900  400.894612
# 1094 -47.023763  181.311186  180.736600  123.430497  166.349918  400.808537
# 1095 -47.180013  181.268741  180.736600  123.438262  166.356637  400.664105
# 1096 -47.242513  181.235054  180.486600  123.447181  166.364639  400.545780
#
#       ADBE_close   ADI_close  ADM_close   ADP_close  ...   WU_close  \
# 0     366.089996  112.269997  45.709999  179.100006  ...  27.650000
# 1     366.089996  112.269997  45.709999  179.100006  ...  27.650000
# 2     366.089996  112.269997  45.709999  179.100006  ...  27.650000
# 3     370.000000  112.900002  45.680000  179.360001  ...  28.299999
# 4     369.279999  116.879997  46.119999  177.970001  ...  28.240000
# ...          ...         ...        ...         ...  ...        ...
# 1092  765.407264  167.719250  40.495848  204.319346  ...  14.648993
# 1093  752.235774  171.030807  40.620848  205.569346  ...  14.943646
# 1094  748.806798  171.022703  39.995848  205.569346  ...  14.961584
# 1095  749.465716  170.961791  39.933348  205.444346  ...  15.010935
# 1096  750.071486  170.915195  39.995848  205.444346  ...  15.056018
#
#       WYNN_close   WY_close  XEL_close  XOM_close  XRAY_close  XRX_close  \
# 0     126.910004  28.580000  68.709999  61.470001   57.099998  37.169998
# 1     126.910004  28.580000  68.709999  61.470001   57.099998  37.169998
# 2     126.910004  28.580000  68.709999  61.470001   57.099998  37.169998
# 3     127.879997  28.650000  69.059998  59.959999   57.450001  37.689999
# 4     131.990005  28.900000  68.959999  60.529999   58.000000  37.509998
# ...          ...        ...        ...        ...         ...        ...
# 1092  -40.046027  19.419445  89.536712   5.075815   33.207364   9.289883
# 1093  -32.171027  20.036632  88.929121   6.888315   34.130341   9.785976
# 1094  -27.921027  19.903820  89.191209   7.107065   34.328326  10.188320
# 1095  -27.921027  19.919445  89.291420   6.857065   34.329779  10.164883
# 1096  -27.858527  19.888195  89.382436   6.732065   34.332634  10.157070
#
#        YUM_close   ZBH_close  ZION_close
# 0     102.040001  151.834946   46.230000
# 1     102.040001  151.834946   46.230000
# 2     102.040001  151.834946   46.230000
# 3     102.870003  153.611649   45.650002
# 4     104.050003  154.650482   46.279999
# ...          ...         ...         ...
# 1092  156.182208  139.992520   -2.621450
# 1093  155.119708  141.117520   -0.746450
# 1094  155.619708  141.242520    0.441050
# 1095  155.557208  141.492520    0.316050
# 1096  155.557208  141.742520    0.253550
#
# [1097 rows x 396 columns]

# %% [markdown]
# # 2. Analysis of correlations

# %%
correlation_matrix = df.corr()

# Find the 30 stocks with the minimal correlation
min_correlation_stocks = correlation_matrix.min().nsmallest(30).index

# Subset the original DataFrame with the selected stocks
selected_stocks = df[min_correlation_stocks]

# %%
expected_returns = df.mean()

# %%
weights = cp.Variable(len(df.columns))

# %%
expected_returns = df.mean()
covariance_matrix = df.cov()

# %%
# Calculate the daily returns for each stock
returns_df = df.pct_change().dropna()
returns_df
# Out:
#       AAL_close  AAPL_close  AAP_close  ABC_close  ABT_close  ACN_close  \
# 1      0.000000    0.000000   0.000000   0.000000   0.000000   0.000000
# 2      0.000000    0.000000   0.000000   0.000000   0.000000   0.000000
# 3      0.014447    0.004750  -0.016926   0.018055   0.004894   0.004585
# 4      0.036471   -0.006033   0.010943   0.010363   0.009853  -0.001929
# 5      0.021113    0.023748   0.016729   0.012795  -0.004261  -0.000707
# ...         ...         ...        ...        ...        ...        ...
# 1092   0.034306    0.008654   0.020864   0.001591   0.003177   0.005858
# 1093  -0.029341   -0.008256  -0.004087  -0.001607  -0.002329  -0.011200
# 1094  -0.011171   -0.009862  -0.010945  -0.008514  -0.005476  -0.000215
# 1095   0.003323   -0.000234   0.000000   0.000063   0.000040  -0.000360
# 1096   0.001325   -0.000186  -0.001383   0.000072   0.000048  -0.000295
#
#       ADBE_close  ADI_close  ADM_close  ADP_close  ...  WU_close  WYNN_close  \
# 1       0.000000   0.000000   0.000000   0.000000  ...  0.000000    0.000000
# 2       0.000000   0.000000   0.000000   0.000000  ...  0.000000    0.000000
# 3       0.010680   0.005612  -0.000656   0.001452  ...  0.023508    0.007643
# 4      -0.001946   0.035252   0.009632  -0.007750  ... -0.002120    0.032140
# 5       0.013567   0.016513  -0.011058   0.000337  ... -0.074717    0.036594
# ...          ...        ...        ...        ...  ...       ...         ...
# 1092    0.002005  -0.010090  -0.001541  -0.002441  ...  0.006145    0.274498
# 1093   -0.017208   0.019745   0.003087   0.006118  ...  0.020114   -0.196649
# 1094   -0.004558  -0.000047  -0.015386   0.000000  ...  0.001200   -0.132106
# 1095    0.000880  -0.000356  -0.001563  -0.000608  ...  0.003299    0.000000
# 1096    0.000808  -0.000273   0.001565   0.000000  ...  0.003003   -0.002238
#
#       WY_close  XEL_close  XOM_close  XRAY_close  XRX_close  YUM_close  \
# 1     0.000000   0.000000   0.000000    0.000000   0.000000   0.000000
# 2     0.000000   0.000000   0.000000    0.000000   0.000000   0.000000
# 3     0.002449   0.005094  -0.024565    0.006130   0.013990   0.008134
# 4     0.008726  -0.001448   0.009506    0.009574  -0.004776   0.011471
# 5     0.029412   0.001015   0.012225    0.000172   0.018129   0.012398
# ...        ...        ...        ...         ...        ...        ...
# 1092 -0.018557   0.004073  -0.220702   -0.009784  -0.036073  -0.007546
# 1093  0.031782  -0.006786   0.357085    0.027794   0.053402  -0.006803
# 1094 -0.006628   0.002947   0.031757    0.005801   0.041114   0.003223
# 1095  0.000785   0.001124  -0.035176    0.000042  -0.002300  -0.000402
# 1096 -0.001569   0.001019  -0.018229    0.000083  -0.000769   0.000000
#
#       ZBH_close  ZION_close
# 1      0.000000    0.000000
# 2      0.000000    0.000000
# 3      0.011702   -0.012546
# 4      0.006763    0.013801
# 5     -0.003704   -0.003673
# ...         ...         ...
# 1092   0.002686    1.806841
# 1093   0.008036   -0.715253
# 1094   0.000886   -1.590863
# 1095   0.001770   -0.283415
# 1096   0.001767   -0.197754
#
# [1096 rows x 396 columns]

# %%
# Calculate the daily returns for each stock
returns_df = df.pct_change().dropna()

# Calculate the expected returns and covariance matrix
expected_returns = returns_df.mean()
covariance_matrix = returns_df.cov()

# Define the objective function to maximize the Sharpe ratio
def objective_function(weights):
    returns = np.dot(weights, expected_returns)
    volatility = np.sqrt(np.dot(weights, np.dot(covariance_matrix, weights.T)))
    sharpe_ratio = returns / volatility
    return -sharpe_ratio  # Negate for maximization

# Define the constraints (e.g., weights sum up to 1)
constraints = [{'type': 'eq', 'fun': lambda x: np.sum(x) - 1},  # Sum of weights equal to 1
               {'type': 'ineq', 'fun': lambda x: x}]  # Non-negative weights

# Define the bounds for the weights (0 <= weight <= 1)
bounds = [(0, 1)] * len(df.columns)

# Set an initial guess for the weights
initial_guess = [1 / len(df.columns)] * len(df.columns)

# Solve the optimization problem
result = minimize(objective_function, initial_guess, method='SLSQP', bounds=bounds, constraints=constraints)
optimal_weights = result.x

# Create a DataFrame with the optimal portfolio weights
portfolio_df = pd.DataFrame({'Stock': df.columns, 'Weight': optimal_weights})

# Sort the DataFrame by weights in descending order
portfolio_df = portfolio_df.sort_values('Weight', ascending=False)

# %% [markdown]
# # 3. Stock Selection

# %%
# Normalize the weights of the top 30 stocks so that they sum up to 1
selected_stocks = portfolio_df[:30]
normalized_weights = selected_stocks['Weight'] / np.sum(selected_stocks['Weight'])

# Assign the normalized weights back to the selected_weights DataFrame
selected_stocks['Normalized_Weight'] = normalized_weights

selected_stocks = selected_stocks.drop(columns=['Weight'])

selected_stocks
# Out:
# /var/folders/l_/s2stp_4940d5h7pgt3_4rl040000gn/T/ipykernel_4539/995650356.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_stocks['Normalized_Weight'] = normalized_weights
#           Stock  Normalized_Weight
# 103   DHR_close           0.164344
# 351  TSCO_close           0.141795
# 211    KR_close           0.116498
# 259   NEM_close           0.076839
# 317   RRC_close           0.066167
# 74    CLX_close           0.053239
# 306  REGN_close           0.049015
# 31   AMZN_close           0.047142
# 368   VLO_close           0.037066
# 39   ATVI_close           0.034219
# 270  NVDA_close           0.029376
# 164    GT_close           0.026462
# 212   KSS_close           0.024458
# 347   TMO_close           0.020495
# 128   EQT_close           0.018406
# 25    AMD_close           0.016219
# 87   COST_close           0.014094
# 342   TAP_close           0.010350
# 147    FL_close           0.009859
# 227   MAC_close           0.007443
# 357   UAL_close           0.006563
# 22    ALK_close           0.004677
# 97    DAL_close           0.004065
# 66    CCL_close           0.004047
# 285   PFG_close           0.003559
# 150   FTI_close           0.003021
# 181   HST_close           0.002791
# 271   NWL_close           0.002688
# 381   WFC_close           0.002663
# 166   HAL_close           0.002437

# %%
selected_stocks.to_csv('selected_stocks(forecast)2.csv',index=False)

# %% [markdown]
# # 4. Repeating the process for historical data

# %%
df=pd.read_csv('historical2.csv')

# %%
df = df.iloc[:, 1:477].copy()

# %%
correlation_matrix = df.corr()

# Find the 30 stocks with the minimal correlation
min_correlation_stocks = correlation_matrix.min().nsmallest(30).index

# Subset the original DataFrame with the selected stocks
selected_stocks = df[min_correlation_stocks]

expected_returns = df.mean()

weights = cp.Variable(len(df.columns))

expected_returns = df.mean()
covariance_matrix = df.cov()

# %%
# Calculate the daily returns for each stock
returns_df = df.pct_change().dropna()

# Calculate the expected returns and covariance matrix
expected_returns = returns_df.mean()
covariance_matrix = returns_df.cov()

# Define the objective function to maximize the Sharpe ratio
def objective_function(weights):
    returns = np.dot(weights, expected_returns)
    volatility = np.sqrt(np.dot(weights, np.dot(covariance_matrix, weights.T)))
    sharpe_ratio = returns / volatility
    return -sharpe_ratio  # Negate for maximization

# Define the constraints (e.g., weights sum up to 1)
constraints = [{'type': 'eq', 'fun': lambda x: np.sum(x) - 1},  # Sum of weights equal to 1
               {'type': 'ineq', 'fun': lambda x: x}]  # Non-negative weights

# Define the bounds for the weights (0 <= weight <= 1)
bounds = [(0, 1)] * len(df.columns)

# Set an initial guess for the weights
initial_guess = [1 / len(df.columns)] * len(df.columns)

# Solve the optimization problem
result = minimize(objective_function, initial_guess, method='SLSQP', bounds=bounds, constraints=constraints)
optimal_weights = result.x

# Create a DataFrame with the optimal portfolio weights
portfolio_df = pd.DataFrame({'Stock': df.columns, 'Weight': optimal_weights})

# Sort the DataFrame by weights in descending order
portfolio_df = portfolio_df.sort_values('Weight', ascending=False)

# %%
# Normalize the weights of the top 30 stocks so that they sum up to 1
selected_stocks = portfolio_df[:30]
normalized_weights = selected_stocks['Weight'] / np.sum(selected_stocks['Weight'])

# Assign the normalized weights back to the selected_weights DataFrame
selected_stocks['Normalized_Weight'] = normalized_weights

selected_stocks = selected_stocks.drop(columns=['Weight'])

selected_stocks
# Out:
# /var/folders/l_/s2stp_4940d5h7pgt3_4rl040000gn/T/ipykernel_4539/995650356.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected_stocks['Normalized_Weight'] = normalized_weights
#           Stock  Normalized_Weight
# 270  NVDA_close       1.869732e-01
# 211    KR_close       1.665118e-01
# 351  TSCO_close       1.587889e-01
# 137   EXR_close       1.440623e-01
# 317   RRC_close       1.258886e-01
# 128   EQT_close       6.223997e-02
# 259   NEM_close       5.932953e-02
# 310   RHI_close       3.628181e-02
# 364   UPS_close       2.989520e-02
# 302   PWR_close       1.944824e-02
# 324   SIG_close       8.294892e-03
# 306  REGN_close       2.285559e-03
# 1    AAPL_close       4.986364e-16
# 3     ABC_close       4.535042e-16
# 4     ABT_close       4.076096e-16
# 32   ANSS_close       3.778177e-16
# 18    AJG_close       3.386209e-16
# 104  DISH_close       2.899211e-16
# 66    CCL_close       2.778500e-16
# 58    BSX_close       2.652940e-16
# 336   STX_close       2.625345e-16
# 50     BA_close       2.534601e-16
# 102   DHI_close       2.481165e-16
# 8     ADM_close       2.415514e-16
# 388    WY_close       2.408009e-16
# 150   FTI_close       2.324995e-16
# 47      A_close       2.277509e-16
# 144  FITB_close       2.273342e-16
# 43    AWK_close       2.215188e-16
# 207  KLAC_close       2.101991e-16

# %%
selected_stocks.to_csv('selected_stocks(historical)2.csv',index=False)
